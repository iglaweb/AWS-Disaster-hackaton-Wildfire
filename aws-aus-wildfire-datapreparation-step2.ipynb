# %% [markdown]
# # Extract fire daily data for Australia

# %% [markdown]
# # 📚 Import Libraries

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from IPython.core.interactiveshell import InteractiveShell
import random
InteractiveShell.ast_node_interactivity = "all"
import os
from datetime import datetime
import glob
from tqdm import tqdm

# %%
FIRMS_FIRE_DAILY = './wildfire-custom-dataset/firms_fire_daily.csv'
full_dataset = pd.read_csv(FIRMS_FIRE_DAILY)
full_dataset.shape
full_dataset.head()

# %% [markdown]
# # 📌 Key-Points

# %% [markdown]
# #### We use coordinate ranges for latitude and longitude belonging only to Australia

# %%
AUS_LAT_RANGE = (-40, -9)
AUS_LON_RANGE = (112, 155)

# %%
aus = full_dataset[
        (full_dataset.latitude > AUS_LAT_RANGE[0]) & (full_dataset.latitude < AUS_LAT_RANGE[1])]
aus = aus[
    (aus.longitude > AUS_LON_RANGE[0]) & (aus.longitude < AUS_LON_RANGE[1])]
aus.shape

# %% [markdown]
# ### Australia fire dataset is ready!

# %%
aus.to_csv('australia_fire_daily.csv.gz', index=False, compression='gzip')
